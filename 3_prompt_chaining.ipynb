# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
    title:str
    outline: str
    content: str

# %%
def create_outline(state:BlogState) ->BlogState:
    title=state['title']
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    state['outline']=outline
    return state

# %%
def create_blog(state: BlogState) ->BlogState:
    title = state['title']
    outline = state['outline']
    
    prompt = f'write a detailsed blog on the title - {title} using the following outline'

    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)
# nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}
final_state =workflow.invoke(intial_state)
final_state
# Out:
# {'title': 'Rise of AI in India',
#  'outline': 'I. Introduction\n    A. Brief overview of AI and its applications\n    B. Introduction to the growing trend of AI adoption in India\n    C. Thesis statement: The rise of AI in India is transforming various industries and boosting economic growth\n    \nII. Historical Overview of AI in India\n    A. Early developments and research in AI in India\n    B. Government initiatives and policies to promote AI adoption\n    C. Growth of AI startups and incubators in India\n    \nIII. AI Applications in Various Industries in India\n    A. Healthcare sector\n        1. Use of AI in diagnostic imaging and personalized medicine\n        2. AI-powered chatbots for patient care and support\n    B. Financial services\n        1. AI in fraud detection and risk management\n        2. Automated customer service through AI-powered virtual assistants\n    C. Manufacturing sector\n        1. AI for predictive maintenance and quality control\n        2. Robotics and automation in manufacturing processes\n        \nIV. Impact of AI on the Indian Economy\n    A. Job displacement and workforce reskilling\n    B. Increased productivity and efficiency\n    C. Opportunities for innovation and entrepreneurship\n    \nV. Challenges and Ethical Considerations\n    A. Data privacy and security concerns\n    B. Bias and discrimination in AI algorithms\n    C. Regulation and governance of AI technologies\n    \nVI. Future Outlook for AI in India\n    A. Continued growth and adoption of AI technologies\n    B. Potential for India to become a global leader in AI innovation\n    C. Recommendations for policymakers, businesses, and individuals to harness the benefits of AI\n    \nVII. Conclusion\n    A. Recap of key points discussed in the blog\n    B. Emphasis on the transformative potential of AI in India\n    C. Call to action for stakeholders to embrace and adapt to the rise of AI in the country.',
#  'content': 'Title: Rise of AI in India\n\nIntroduction\n- Definition and significance of AI\n- Introduction to AI in India\n\nOverview of AI in India\n- Current status of AI in India\n- Growth and development of AI in India\n\nApplications of AI in India\n- AI in healthcare\n- AI in agriculture\n- AI in finance\n- AI in education\n\nChallenges and opportunities\n- Challenges facing the adoption of AI in India\n- Opportunities for growth and development in the AI sector in India\n\nGovernment initiatives\n- Government policies and strategies to promote AI in India\n- Public-private partnerships in the AI sector\n\nFuture of AI in India\n- Potential growth and opportunities in the AI sector\n- Challenges and considerations for the future of AI in India\n\nImpact of AI in India\n- Economic impact of AI in India\n- Social impact of AI in India\n- Ethical considerations of AI in India\n\nConclusion\n- Summary of key points\n- Final thoughts on the rise of AI in India'}

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of AI and its applications
#     B. Introduction to the growing trend of AI adoption in India
#     C. Thesis statement: The rise of AI in India is transforming various industries and boosting economic growth
#
# II. Historical Overview of AI in India
#     A. Early developments and research in AI in India
#     B. Government initiatives and policies to promote AI adoption
#     C. Growth of AI startups and incubators in India
#
# III. AI Applications in Various Industries in India
#     A. Healthcare sector
#         1. Use of AI in diagnostic imaging and personalized medicine
#         2. AI-powered chatbots for patient care and support
#     B. Financial services
#         1. AI in fraud detection and risk management
#         2. Automated customer service through AI-powered virtual assistants
#     C. Manufacturing sector
#         1. AI for predictive maintenance and quality control
#         2. Robotics and automation in manufacturing processes
#
# IV. Impact of AI on the Indian Economy
#     A. Job displacement and workforce reskilling
#     B. Increased productivity and efficiency
#     C. Opportunities for innovation and entrepreneurship
#
# V. Challenges and Ethical Considerations
#     A. Data privacy and security concerns
#     B. Bias and discrimination in AI algorithms
#     C. Regulation and governance of AI technologies
#
# VI. Future Outlook for AI in India
#     A. Continued growth and adoption of AI technologies
#     B. Potential for India to become a global leader in AI innovation
#     C. Recommendations for policymakers, businesses, and individuals to harness the benefits of AI
#
# VII. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Emphasis on the transformative potential of AI in India
#     C. Call to action for stakeholders to embrace and adapt to the rise of AI in the country.

# %%
print(final_state['content'])
# Out:
# Title: Rise of AI in India
#
# Introduction
# - Definition and significance of AI
# - Introduction to AI in India
#
# Overview of AI in India
# - Current status of AI in India
# - Growth and development of AI in India
#
# Applications of AI in India
# - AI in healthcare
# - AI in agriculture
# - AI in finance
# - AI in education
#
# Challenges and opportunities
# - Challenges facing the adoption of AI in India
# - Opportunities for growth and development in the AI sector in India
#
# Government initiatives
# - Government policies and strategies to promote AI in India
# - Public-private partnerships in the AI sector
#
# Future of AI in India
# - Potential growth and opportunities in the AI sector
# - Challenges and considerations for the future of AI in India
#
# Impact of AI in India
# - Economic impact of AI in India
# - Social impact of AI in India
# - Ethical considerations of AI in India
#
# Conclusion
# - Summary of key points
# - Final thoughts on the rise of AI in India
